# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split,cross_validate
from sklearn.metrics import accuracy_score,confusion_matrix,log_loss
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv("students_data.csv")
df.drop("StudentID",axis=1,inplace=True)
df
# Out:
#      Gender  StudyHours  Attendance InternetAccess ExtraClasses  \
# 0      Male         3.0        87.9            Yes           No
# 1    Female        18.1        51.2            Yes           No
# 2      Male        10.6        51.1             No           No
# 3      Male        16.7        66.2            Yes           No
# 4      Male         7.1        74.4            Yes          Yes
# ..      ...         ...         ...            ...          ...
# 795    Male        17.6        82.8            Yes           No
# 796    Male        19.5        97.8            Yes          Yes
# 797    Male        19.4        53.4            Yes          Yes
# 798    Male        15.2        52.9             No          Yes
# 799    Male         3.5        64.1            Yes           No
#
#     ParentalSupport SportsActivity Performance
# 0               Low            Yes      Medium
# 1            Medium             No      Medium
# 2               Low            Yes         Low
# 3               Low            Yes      Medium
# 4               Low             No      Medium
# ..              ...            ...         ...
# 795            High             No        High
# 796             Low             No        High
# 797             Low            Yes        High
# 798             Low            Yes      Medium
# 799             Low            Yes      Medium
#
# [800 rows x 8 columns]

# %%
label=LabelEncoder()
for i in df.select_dtypes(include=["object"]):
    df[i]=label.fit_transform(df[i])

df
# Out:
#      Gender  StudyHours  Attendance  InternetAccess  ExtraClasses  \
# 0         1         3.0        87.9               1             0
# 1         0        18.1        51.2               1             0
# 2         1        10.6        51.1               0             0
# 3         1        16.7        66.2               1             0
# 4         1         7.1        74.4               1             1
# ..      ...         ...         ...             ...           ...
# 795       1        17.6        82.8               1             0
# 796       1        19.5        97.8               1             1
# 797       1        19.4        53.4               1             1
# 798       1        15.2        52.9               0             1
# 799       1         3.5        64.1               1             0
#
#      ParentalSupport  SportsActivity  Performance
# 0                  1               1            2
# 1                  2               0            2
# 2                  1               1            1
# 3                  1               1            2
# 4                  1               0            2
# ..               ...             ...          ...
# 795                0               0            0
# 796                1               0            0
# 797                1               1            0
# 798                1               1            2
# 799                1               1            2
#
# [800 rows x 8 columns]

# %%
x=df.drop("Performance",axis=1)
y=df["Performance"]
y
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      2
#       ..
# 795    0
# 796    0
# 797    0
# 798    2
# 799    2
# Name: Performance, Length: 800, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LogisticRegression(max_iter=50)
model.fit(x_train,y_train)
# Out:
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 50 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=50).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=50)

# %%
cross=cross_validate(model,x,y,cv=5,return_train_score=True)
cross
# Out:
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 50 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=50).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 50 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=50).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 50 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=50).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 50 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=50).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 50 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=50).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# {'fit_time': array([0.03779769, 0.02023101, 0.02320075, 0.01673937, 0.02387929]),
#  'score_time': array([0.00349331, 0.00183606, 0.00194407, 0.00137687, 0.00200129]),
#  'test_score': array([0.80625, 0.80625, 0.8    , 0.825  , 0.8125 ]),
#  'train_score': array([0.8265625, 0.8265625, 0.8359375, 0.8234375, 0.8265625])}

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([2, 2, 0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 0, 2, 2, 0, 2, 2, 2, 2, 2, 2,
#        0, 0, 2, 2, 2, 0, 0, 0, 2, 0, 0, 2, 2, 0, 2, 0, 0, 2, 2, 2, 0, 0,
#        2, 2, 0, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 0, 2,
#        0, 2, 2, 0, 2, 2, 2, 2, 2, 2, 0, 0, 2, 2, 0, 2, 2, 0, 2, 2, 0, 2,
#        2, 0, 0, 2, 0, 0, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0,
#        0, 2, 2, 2, 0, 0, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 0, 2, 2, 0, 2, 2,
#        0, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#        0, 2, 0, 2, 0, 2])

# %%
accuracy=accuracy_score(y_pred,y_test)
print(f"accuracy:{accuracy*100:.2f}%")
# Out:
# accuracy:80.62%

# %%
y_prob=model.predict_proba(x_test)
y_prob
# Out:
# array([[4.57335150e-03, 1.53271209e-02, 9.80099528e-01],
#        [1.51428120e-01, 9.37342771e-02, 7.54837603e-01],
#        [5.00431833e-01, 6.78136008e-03, 4.92786807e-01],
#        [1.13380868e-01, 1.20710639e-02, 8.74548069e-01],
#        [9.38702443e-01, 6.37626586e-03, 5.49212916e-02],
#        [5.82345075e-02, 7.38730993e-02, 8.67892393e-01],
#        [6.71569633e-03, 1.06390123e-02, 9.82645291e-01],
#        [9.95180281e-01, 1.41194406e-04, 4.67852448e-03],
#        [9.42289307e-01, 5.87552565e-04, 5.71231407e-02],
#        [3.40865063e-01, 8.68430107e-02, 5.72291926e-01],
#        [4.88147947e-01, 3.30870054e-02, 4.78765048e-01],
#        [7.99487410e-01, 5.58930915e-03, 1.94923281e-01],
#        [7.89925341e-01, 3.18485502e-03, 2.06889804e-01],
#        [4.09140575e-01, 1.88383449e-03, 5.88975590e-01],
#        [1.29080177e-01, 3.02302750e-03, 8.67896795e-01],
#        [9.13389784e-01, 7.55189987e-04, 8.58550256e-02],
#        [1.54073834e-03, 2.79412088e-02, 9.70518053e-01],
#        [4.52875834e-02, 3.63348728e-03, 9.51078929e-01],
#        [1.05491449e-01, 3.56614311e-02, 8.58847119e-01],
#        [4.40578754e-03, 1.92663943e-02, 9.76327818e-01],
#        [3.64724773e-02, 9.88925015e-03, 9.53638273e-01],
#        [5.03318467e-02, 4.50782786e-02, 9.04589875e-01],
#        [5.53765266e-01, 7.71107470e-04, 4.45463627e-01],
#        [9.38445832e-01, 2.31814474e-04, 6.13223532e-02],
#        [1.83328653e-01, 8.84378628e-02, 7.28233484e-01],
#        [8.63434642e-02, 2.96824842e-02, 8.83974052e-01],
#        [9.65716030e-01, 2.82817590e-04, 3.40011520e-02],
#        [1.60702734e-01, 9.35378094e-02, 7.45759456e-01],
#        [9.77401915e-03, 7.83601446e-02, 9.11865836e-01],
#        [1.04123033e-02, 2.35546758e-02, 9.66033021e-01],
#        [8.18119409e-01, 1.47751598e-03, 1.80403075e-01],
#        [4.33557189e-02, 6.87321821e-02, 8.87912099e-01],
#        [2.02843993e-01, 4.31014949e-02, 7.54054512e-01],
#        [9.28046628e-01, 5.27958955e-04, 7.14254129e-02],
#        [2.06515578e-02, 2.54814382e-03, 9.76800298e-01],
#        [8.37320499e-02, 2.55632591e-02, 8.90704691e-01],
#        [7.61376544e-01, 2.73287739e-03, 2.35890579e-01],
#        [2.40167733e-01, 1.01738710e-03, 7.58814880e-01],
#        [7.10155217e-02, 1.78394665e-02, 9.11145012e-01],
#        [9.77428298e-01, 3.19673192e-04, 2.22520292e-02],
#        [4.21638914e-01, 2.09352098e-03, 5.76267565e-01],
#        [2.47446365e-01, 3.01393663e-02, 7.22414269e-01],
#        [2.41435658e-01, 1.82426104e-03, 7.56740081e-01],
#        [3.55341049e-02, 5.02704821e-02, 9.14195413e-01],
#        [4.15079637e-01, 3.89529260e-03, 5.81025070e-01],
#        [2.61389833e-01, 1.15352275e-03, 7.37456644e-01],
#        [3.93009310e-01, 5.50976586e-02, 5.51893031e-01],
#        [9.94685424e-01, 1.49920835e-04, 5.16465542e-03],
#        [3.99995399e-02, 8.64561167e-02, 8.73544343e-01],
#        [7.50789925e-01, 7.80883144e-03, 2.41401243e-01],
#        [4.62881610e-02, 7.54254888e-03, 9.46169290e-01],
#        [6.45964748e-04, 2.03133197e-02, 9.79040716e-01],
#        [1.15556638e-01, 1.38434462e-03, 8.83059017e-01],
#        [4.42955026e-02, 1.48575660e-03, 9.54218741e-01],
#        [3.31326637e-01, 1.21028965e-02, 6.56570466e-01],
#        [8.45144715e-02, 2.11411384e-02, 8.94344390e-01],
#        [2.42868101e-03, 8.67624981e-03, 9.88895069e-01],
#        [1.23405616e-01, 3.31860084e-03, 8.73275783e-01],
#        [5.38225215e-01, 5.35845981e-02, 4.08190187e-01],
#        [4.29269024e-01, 1.51185262e-03, 5.69219123e-01],
#        [6.92413463e-01, 4.86522599e-03, 3.02721311e-01],
#        [3.62584797e-03, 1.59815214e-02, 9.80392631e-01],
#        [8.39057421e-01, 8.80892730e-03, 1.52133652e-01],
#        [6.74972211e-03, 1.33387731e-02, 9.79911505e-01]])

# %%
loss=log_loss(y_test,y_prob)
loss
# Out:
# 0.4745376461666164

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(cm,annot=True,fmt="d",cmap="Blues")
plt.show()

# %%
data=pd.DataFrame({
    "Gender":label.fit_transform(["Male"]),
    "StudyHours":[3.0],   
    "Attendance":["87.9"],
    "InternetAccess":label.fit_transform(["Yes"]),
    "ExtraClasses":label.fit_transform(["No"]),
    "ParentalSupport":label.fit_transform(["Medium"]),
    "SportsActivity":label.fit_transform(["No"])
})
pre=model.predict(data)
pre
# Out:
# array([2])
