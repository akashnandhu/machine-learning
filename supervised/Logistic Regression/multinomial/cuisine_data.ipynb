# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split,cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,log_loss,confusion_matrix

# %%
df=pd.read_csv("cuisine_data.csv")
df.drop("CustomerID",axis=1,inplace=True)
df
# Out:
#      Gender  Age  CityType IncomeLevel  OrdersPerMonth Vegetarian  \
# 0      Male   58     Urban      Medium               8         No
# 1    Female   47     Urban      Medium              23         No
# 2      Male   34     Urban         Low               9        Yes
# 3      Male   37     Rural         Low               2        Yes
# 4      Male   42     Rural      Medium              14        Yes
# ..      ...  ...       ...         ...             ...        ...
# 795    Male   34     Urban      Medium              15         No
# 796    Male   54     Rural      Medium              10         No
# 797    Male   42  Suburban      Medium               9        Yes
# 798    Male   55  Suburban        High               1        Yes
# 799    Male   29     Urban      Medium              16        Yes
#
#     SpicyPreference CuisinePreference
# 0            Medium           Chinese
# 1               Low           Italian
# 2              High            Indian
# 3               Low            Indian
# 4               Low           Chinese
# ..              ...               ...
# 795          Medium           Italian
# 796          Medium           Mexican
# 797            High           Chinese
# 798            High            Indian
# 799             Low           Italian
#
# [800 rows x 8 columns]

# %%
label=LabelEncoder()
for i in df.select_dtypes(include=["object"]):
    df[i]=label.fit_transform(df[i])
df
# Out:
#      Gender  Age  CityType  IncomeLevel  OrdersPerMonth  Vegetarian  \
# 0         1   58         2            2               8           0
# 1         0   47         2            2              23           0
# 2         1   34         2            1               9           1
# 3         1   37         0            1               2           1
# 4         1   42         0            2              14           1
# ..      ...  ...       ...          ...             ...         ...
# 795       1   34         2            2              15           0
# 796       1   54         0            2              10           0
# 797       1   42         1            2               9           1
# 798       1   55         1            0               1           1
# 799       1   29         2            2              16           1
#
#      SpicyPreference  CuisinePreference
# 0                  2                  0
# 1                  1                  2
# 2                  0                  1
# 3                  1                  1
# 4                  1                  0
# ..               ...                ...
# 795                2                  2
# 796                2                  3
# 797                0                  0
# 798                0                  1
# 799                1                  2
#
# [800 rows x 8 columns]

# %%
x=df.drop("CuisinePreference",axis=1)
y=df["CuisinePreference"]
y
# Out:
# 0      0
# 1      2
# 2      1
# 3      1
# 4      0
#       ..
# 795    2
# 796    3
# 797    0
# 798    1
# 799    2
# Name: CuisinePreference, Length: 800, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
cross=cross_validate(model,x,y,cv=5,return_train_score=True)
cross
# Out:
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# {'fit_time': array([0.04455495, 0.03436708, 0.03640914, 0.03620815, 0.03441477]),
#  'score_time': array([0.00166535, 0.00131941, 0.00226331, 0.0018332 , 0.00142622]),
#  'test_score': array([0.36875, 0.525  , 0.39375, 0.4125 , 0.35625]),
#  'train_score': array([0.4421875, 0.4      , 0.4484375, 0.4109375, 0.45     ])}

# %%
y_prob=model.predict_proba(x_test)
y_prob
# Out:
# array([[0.16651723, 0.19068384, 0.08172247, 0.56107646],
#        [0.15739781, 0.43349476, 0.25153925, 0.15756818],
#        [0.11595014, 0.57501469, 0.11876268, 0.19027249],
#        [0.39232191, 0.07720182, 0.1173855 , 0.41309077],
#        [0.41955308, 0.05973397, 0.22091422, 0.29979873],
#        [0.36801534, 0.13761375, 0.40878524, 0.08558567],
#        [0.25507084, 0.27970871, 0.19208395, 0.2731365 ],
#        [0.21600953, 0.15008147, 0.22911805, 0.40479095],
#        [0.41037817, 0.07679894, 0.3539272 , 0.15889569],
#        [0.09376302, 0.46015526, 0.39543667, 0.05064505],
#        [0.09823637, 0.43602516, 0.34180363, 0.12393484],
#        [0.15288326, 0.40168921, 0.06707408, 0.37835345],
#        [0.2037938 , 0.35343123, 0.14652578, 0.29624919],
#        [0.1996637 , 0.30090837, 0.08211109, 0.41731684],
#        [0.27384132, 0.11243938, 0.06877372, 0.54494557],
#        [0.30876638, 0.06614764, 0.56939028, 0.0556957 ],
#        [0.25534034, 0.14013276, 0.14929666, 0.45523024],
#        [0.65024373, 0.03155871, 0.11384369, 0.20435387],
#        [0.54001365, 0.05783534, 0.11384324, 0.28830777],
#        [0.27030471, 0.27874337, 0.12740514, 0.32354679],
#        [0.24186754, 0.23388049, 0.28560259, 0.23864937],
#        [0.09616247, 0.43226129, 0.22585116, 0.24572509],
#        [0.29854539, 0.22317951, 0.17962663, 0.29864846],
#        [0.25650972, 0.2493427 , 0.13986539, 0.35428219],
#        [0.5018505 , 0.0478199 , 0.13713562, 0.31319398],
#        [0.14309535, 0.44146165, 0.13826521, 0.27717778],
#        [0.23684198, 0.35380802, 0.24134044, 0.16800956],
#        [0.14436991, 0.36617074, 0.42791621, 0.06154314],
#        [0.46296278, 0.06359402, 0.31555449, 0.1578887 ],
#        [0.25587423, 0.1581113 , 0.48615237, 0.09986209],
#        [0.49392183, 0.04986209, 0.1358516 , 0.32036449],
#        [0.19410845, 0.16044408, 0.05173233, 0.59371514],
#        [0.40827065, 0.05939882, 0.22754326, 0.30478727],
#        [0.32292645, 0.17183403, 0.19194723, 0.31329228],
#        [0.48046283, 0.05592726, 0.18096273, 0.28264718],
#        [0.47770179, 0.0332452 , 0.25485939, 0.23419362],
#        [0.6260231 , 0.03104972, 0.12526867, 0.2176585 ],
#        [0.03179562, 0.64270456, 0.04913889, 0.27636093],
#        [0.34185447, 0.11125914, 0.05646972, 0.49041667],
#        [0.12617316, 0.41764694, 0.27426863, 0.18191127],
#        [0.25695956, 0.13235162, 0.06847571, 0.54221311],
#        [0.25185738, 0.11424021, 0.22702987, 0.40687254],
#        [0.47598933, 0.09081696, 0.26249069, 0.17070301],
#        [0.45804027, 0.08931517, 0.2615833 , 0.19106126],
#        [0.24322935, 0.24509886, 0.22174698, 0.28992481],
#        [0.38177537, 0.08579315, 0.08301995, 0.44941153],
#        [0.12445848, 0.43605226, 0.08041946, 0.3590698 ],
#        [0.16957086, 0.2332553 , 0.07299337, 0.52418047],
#        [0.32066648, 0.22953422, 0.29339294, 0.15640636],
#        [0.09740849, 0.42754814, 0.07946699, 0.39557638],
#        [0.27654248, 0.22375373, 0.26732225, 0.23238155],
#        [0.20967855, 0.22835715, 0.31342462, 0.24853967],
#        [0.38754382, 0.17536016, 0.32556144, 0.11153458],
#        [0.3447556 , 0.09064833, 0.18499334, 0.37960273],
#        [0.35598874, 0.04211906, 0.54785668, 0.05403552],
#        [0.15990073, 0.35564519, 0.3442382 , 0.14021589],
#        [0.29869337, 0.11084839, 0.0694786 , 0.52097964],
#        [0.37997703, 0.13296895, 0.24639762, 0.24065639],
#        [0.13963338, 0.52870071, 0.24642197, 0.08524393],
#        [0.52184371, 0.05191317, 0.12689768, 0.29934544],
#        [0.17100957, 0.40416826, 0.21654842, 0.20827375],
#        [0.58421873, 0.04137818, 0.1385573 , 0.2358458 ],
#        [0.38177537, 0.08579315, 0.08301995, 0.44941153],
#        [0.23458088, 0.24909309, 0.22052881, 0.29579722],
#        [0.17091722, 0.38075973, 0.38898586, 0.05933718],
#        [0.09607483, 0.24583943, 0.06529318, 0.59279256],
#        [0.05087878, 0.71119421, 0.16530928, 0.07261773],
#        [0.57775873, 0.03713478, 0.14424665, 0.24085984],
#        [0.50634863, 0.04757414, 0.33628227, 0.10979497],
#        [0.19477588, 0.20344448, 0.07225391, 0.52952573],
#        [0.33283031, 0.12998549, 0.43758368, 0.09960052],
#        [0.43837045, 0.12383683, 0.24687759, 0.19091514],
#        [0.12162556, 0.43417606, 0.1537041 , 0.29049428],
#        [0.25792237, 0.20318097, 0.27528003, 0.26361663],
#        [0.46625735, 0.08474796, 0.27413542, 0.17485927],
#        [0.36620363, 0.16396462, 0.34110367, 0.12872808],
#        [0.09489729, 0.60648158, 0.12017673, 0.17844441],
#        [0.37636891, 0.08076185, 0.23220386, 0.31066538],
#        [0.33568418, 0.10814722, 0.48348091, 0.07268768],
#        [0.23593312, 0.18324517, 0.36386172, 0.21695998],
#        [0.31565286, 0.19745882, 0.20006401, 0.2868243 ],
#        [0.35379888, 0.14875185, 0.25334147, 0.2441078 ],
#        [0.2757495 , 0.27288114, 0.29650656, 0.1548628 ],
#        [0.52075235, 0.03803743, 0.223497  , 0.21771322],
#        [0.12922477, 0.4316597 , 0.25854001, 0.18057552],
#        [0.47256149, 0.08213767, 0.25308368, 0.19221716],
#        [0.41037121, 0.10057631, 0.334189  , 0.15486348],
#        [0.22675106, 0.30692827, 0.19481794, 0.27150274],
#        [0.29716906, 0.14636864, 0.13077929, 0.42568301],
#        [0.23603493, 0.2209827 , 0.29841646, 0.24456591],
#        [0.3591024 , 0.14456204, 0.37005381, 0.12628174],
#        [0.36095306, 0.13821427, 0.36677778, 0.1340549 ],
#        [0.29779396, 0.11189894, 0.04288574, 0.54742135],
#        [0.15025355, 0.39543185, 0.08132347, 0.37299113],
#        [0.12265203, 0.3224872 , 0.51006106, 0.04479972],
#        [0.39887041, 0.15599719, 0.16091812, 0.28421427],
#        [0.26774738, 0.16815251, 0.2908057 , 0.2732944 ],
#        [0.27945421, 0.26626557, 0.31199072, 0.14228951],
#        [0.53353994, 0.05147286, 0.08359382, 0.33139339],
#        [0.58188455, 0.04342269, 0.2424463 , 0.13224646],
#        [0.55908455, 0.04285109, 0.11365734, 0.28440702],
#        [0.19010608, 0.1785631 , 0.08065933, 0.55067149],
#        [0.16362809, 0.44028398, 0.23864893, 0.157439  ],
#        [0.13131642, 0.49195975, 0.28358971, 0.09313411],
#        [0.51701397, 0.04102393, 0.17170834, 0.27025375],
#        [0.19717717, 0.22292528, 0.10647951, 0.47341804],
#        [0.65966138, 0.02045816, 0.11674479, 0.20313567],
#        [0.06937973, 0.71931145, 0.14081889, 0.07048993],
#        [0.41917604, 0.05966858, 0.11523519, 0.4059202 ],
#        [0.1997243 , 0.28836893, 0.17678457, 0.33512221],
#        [0.21638806, 0.36661309, 0.13149543, 0.28550343]])

# %%
loss=log_loss(y_test,y_prob)
loss
# Out:
# 1.300524940649358

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([3, 1, 1, 3, 0, 2, 1, 3, 0, 1, 1, 1, 1, 3, 3, 2, 3, 0, 0, 3, 2, 1,
#        3, 3, 0, 1, 1, 2, 0, 2, 0, 3, 0, 0, 0, 0, 0, 1, 3, 1, 3, 3, 0, 2,
#        3, 0, 3, 3, 3, 3, 1, 0, 3, 1, 3, 1, 0, 3, 3, 0, 3, 3, 1, 0, 1, 3,
#        3, 0, 3, 2, 0, 0, 0, 0, 0, 3, 1, 0, 2, 3, 0, 2, 0, 0, 3, 1, 0, 1,
#        3, 3, 2, 0, 0, 3, 3, 1, 3, 0, 1, 0, 2, 0, 3, 2, 1, 3, 0, 1, 0, 1,
#        0, 3, 3, 2, 3, 1, 0, 0, 3, 2, 0, 1, 2, 0, 0, 1, 0, 2, 2, 0, 0, 2,
#        0, 1, 0, 0, 1, 3, 2, 2, 2, 3, 1, 2, 0, 2, 2, 0, 0, 0, 3, 1, 1, 0,
#        3, 0, 1, 0, 3, 1])

# %%
accuracy=accuracy_score(y_pred,y_test)
print(f"accuracy:{accuracy*100:.2f}%")
# Out:
# accuracy:36.88%

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
plt.figure(figsize=[10,6])
sns.heatmap(cm,annot=True,fmt="d",cmap="Blues")
plt.show()

# %%
data=pd.DataFrame({
    "Gender":label.fit_transform(["Male"]),
    "Age":[58],
    "CityType":label.fit_transform(["Urban"]),
    "IncomeLevel":label.fit_transform(["Medium"]),
    "OrdersPerMonth":[8],
    "Vegetarian":label.fit_transform(["No"]),
    "SpicyPreference":label.fit_transform(["Medium"])

})

pre=model.predict(data)
pre
# Out:
# array([1])
