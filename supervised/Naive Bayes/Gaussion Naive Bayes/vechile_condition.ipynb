# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("vehicle_condition.csv")
df
# Out:
#      Engine_Temp  Oil_Pressure          RPM  Vibration_Level Condition
# 0      94.967142    369.967772  2229.928690         1.092192      Good
# 1      88.617357    346.231684  2442.192532         2.139615      Good
# 2      96.476885    302.981518  2183.032032         2.586394      Good
# 3     105.230299    267.653161  2376.815388         4.887688    Faulty
# 4      87.658466    334.911166  1742.554133         3.556553      Good
# ..           ...           ...          ...              ...       ...
# 995    87.188997    353.507512  2530.992207         3.028458      Good
# 996   107.976865    298.673937  2603.101016         0.922188    Faulty
# 997    96.408429    255.906267  2003.295770         2.679702      Good
# 998    84.288210    291.846652  2633.670567         4.643378    Faulty
# 999    95.725828    262.754868  2437.896380         3.360648      Good
#
# [1000 rows x 5 columns]

# %%
x=df.drop("Condition",axis=1)
# x=df.drop(columns=["Performance"])
x
y=df["Condition"]
y
# Out:
# 0        Good
# 1        Good
# 2        Good
# 3      Faulty
# 4        Good
#         ...
# 995      Good
# 996    Faulty
# 997      Good
# 998    Faulty
# 999      Good
# Name: Condition, Length: 1000, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Faulty', 'Faulty', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Faulty', 'Good', 'Good', 'Good', 'Faulty', 'Faulty', 'Faulty',
#        'Good', 'Good', 'Good', 'Faulty', 'Good', 'Faulty', 'Good', 'Good',
#        'Good', 'Good', 'Faulty', 'Good', 'Faulty', 'Faulty', 'Good',
#        'Good', 'Faulty', 'Good', 'Faulty', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Faulty', 'Faulty', 'Good', 'Faulty', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Faulty',
#        'Good', 'Good', 'Good', 'Good', 'Faulty', 'Good', 'Good', 'Good',
#        'Faulty', 'Faulty', 'Good', 'Faulty', 'Good', 'Good', 'Faulty',
#        'Good', 'Good', 'Faulty', 'Faulty', 'Good', 'Faulty', 'Good',
#        'Good', 'Faulty', 'Good', 'Good', 'Good', 'Good', 'Faulty',
#        'Faulty', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Faulty',
#        'Good', 'Good', 'Good', 'Good', 'Faulty', 'Good', 'Faulty',
#        'Faulty', 'Good', 'Faulty', 'Faulty', 'Faulty', 'Faulty', 'Good',
#        'Faulty', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Faulty',
#        'Good', 'Good', 'Faulty', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Faulty', 'Faulty', 'Good', 'Good', 'Good', 'Good',
#        'Faulty', 'Good', 'Good', 'Good', 'Good', 'Good', 'Faulty', 'Good',
#        'Good', 'Good', 'Faulty', 'Faulty', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Faulty', 'Faulty', 'Good', 'Faulty', 'Faulty',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Faulty', 'Good', 'Good',
#        'Good', 'Good', 'Faulty', 'Faulty', 'Faulty', 'Good', 'Faulty',
#        'Faulty', 'Good', 'Good', 'Good', 'Faulty', 'Good', 'Faulty',
#        'Faulty', 'Good', 'Faulty', 'Faulty', 'Faulty', 'Good', 'Faulty',
#        'Good', 'Faulty', 'Faulty', 'Faulty', 'Good', 'Good', 'Faulty',
#        'Faulty', 'Faulty', 'Faulty', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Faulty', 'Good', 'Good'],
#       dtype='<U6')

# %%
accuracy=accuracy_score(y_pred,y_test)
print(f"accuracy is:{accuracy*100:.2f}%")
# Out:
# accuracy is:87.50%

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 63,  18],
#        [  7, 112]])

# %%
plt.figure(figsize=[10,6])
sns.heatmap(cm,annot=True,cmap="Blues",fmt="d")
plt.show()

# %%
new=np.array([[38.476999,16.996777,36.624109,65.921924]])
new_data=model.predict(new)
new_data
# Out:
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['Faulty'], dtype='<U6')
