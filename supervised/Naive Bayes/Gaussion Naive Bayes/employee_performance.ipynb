# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("employee_performance.csv")
df
# Out:
#            Age  Experience_Years  Average_Hours_Worked  Task_Completion_Rate  \
# 0    38.476999         16.996777             36.624109             65.921924
# 1    34.032150         14.623168             39.277407             76.396150
# 2    39.533820         10.298152             36.037900             80.863945
# 3    45.661209          6.765316             38.460192            100.000000
# 4    33.360926         13.491117             30.531927             90.565531
# ..         ...               ...                   ...                   ...
# 995  33.032298         15.350751             40.387403             85.284576
# 996  47.583806          9.867394             41.288763             64.221882
# 997  39.485900          5.590627             33.791197             81.797022
# 998  31.001747          9.184665             41.670882            100.000000
# 999  39.008079          6.275487             39.223705             88.606479
#
#     Performance
# 0          Poor
# 1          Poor
# 2          Good
# 3          Good
# 4          Poor
# ..          ...
# 995        Good
# 996        Poor
# 997        Poor
# 998        Good
# 999        Good
#
# [1000 rows x 5 columns]

# %%
x=df.drop("Performance",axis=1)
# x=df.drop(columns=["Performance"])
x
y=df["Performance"]
y
# Out:
# 0      Poor
# 1      Poor
# 2      Good
# 3      Good
# 4      Poor
#        ...
# 995    Good
# 996    Poor
# 997    Poor
# 998    Good
# 999    Good
# Name: Performance, Length: 1000, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Poor', 'Poor', 'Poor', 'Poor', 'Good', 'Good', 'Poor', 'Poor',
#        'Good', 'Good', 'Good', 'Good', 'Poor', 'Good', 'Poor', 'Good',
#        'Poor', 'Poor', 'Good', 'Good', 'Good', 'Poor', 'Poor', 'Good',
#        'Poor', 'Good', 'Poor', 'Good', 'Good', 'Poor', 'Poor', 'Poor',
#        'Good', 'Good', 'Good', 'Poor', 'Poor', 'Good', 'Poor', 'Poor',
#        'Poor', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Poor',
#        'Poor', 'Good', 'Good', 'Poor', 'Good', 'Poor', 'Good', 'Poor',
#        'Poor', 'Poor', 'Good', 'Poor', 'Good', 'Poor', 'Good', 'Good',
#        'Good', 'Good', 'Poor', 'Good', 'Poor', 'Poor', 'Good', 'Poor',
#        'Good', 'Good', 'Good', 'Poor', 'Good', 'Poor', 'Poor', 'Good',
#        'Poor', 'Poor', 'Good', 'Good', 'Good', 'Poor', 'Good', 'Good',
#        'Poor', 'Poor', 'Good', 'Poor', 'Poor', 'Poor', 'Poor', 'Good',
#        'Good', 'Poor', 'Poor', 'Poor', 'Good', 'Poor', 'Good', 'Poor',
#        'Good', 'Poor', 'Poor', 'Good', 'Good', 'Good', 'Poor', 'Poor',
#        'Poor', 'Poor', 'Good', 'Good', 'Poor', 'Good', 'Good', 'Poor',
#        'Poor', 'Poor', 'Poor', 'Good', 'Poor', 'Poor', 'Poor', 'Poor',
#        'Good', 'Poor', 'Poor', 'Poor', 'Good', 'Good', 'Poor', 'Poor',
#        'Poor', 'Good', 'Good', 'Good', 'Good', 'Poor', 'Good', 'Good',
#        'Poor', 'Poor', 'Poor', 'Good', 'Good', 'Poor', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Poor', 'Good', 'Poor',
#        'Poor', 'Good', 'Poor', 'Good', 'Poor', 'Good', 'Poor', 'Good',
#        'Good', 'Poor', 'Poor', 'Good', 'Poor', 'Poor', 'Poor', 'Poor',
#        'Good', 'Good', 'Poor', 'Poor', 'Good', 'Good', 'Poor', 'Good',
#        'Poor', 'Poor', 'Poor', 'Good', 'Poor', 'Poor', 'Good', 'Good',
#        'Poor', 'Good', 'Good', 'Good', 'Poor', 'Good', 'Good', 'Good'],
#       dtype='<U4')

# %%
accuracy=accuracy_score(y_pred,y_test)
print(f"accuracy is:{accuracy*100:.2f}%")
# Out:
# accuracy is:87.00%

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[86, 12],
#        [14, 88]])

# %%
plt.figure(figsize=[10,6])
sns.heatmap(cm,annot=True,cmap="Blues",fmt="d")
plt.show()

# %%
new=np.array([[38.476999,16.996777,36.624109,65.921924]])
new_data=model.predict(new)
new_data
# Out:
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['Poor'], dtype='<U4')
